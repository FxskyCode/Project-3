# %% [markdown]
# # MAPS

# %%
from pymongo import MongoClient
import pandas as pd
import os
import requests
import json
from dotenv import load_dotenv
from bs4 import BeautifulSoup
import re
import geopandas as gpd
from cartoframes.viz import Map, Layer, popup_element
import numpy as np

import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster

# %%
df = pd.read_csv("../data/five_locations.csv", encoding= "unicode_escape")
df
# Out:
#             name    city   latitude  longitude  airport_dist  airport_lat  \
# 0           PCIQ  London  51.515374  -0.130109       23305.0    51.470012
# 1   Filmed Media  London  51.535901  -0.205508       19001.0    51.470012
# 2        Zensify  London  51.494076  -0.146659       21778.0    51.470012
# 3      ProcServe  London  51.494067  -0.146665       21778.0    51.470012
# 4  ArcelorMittal  London  51.509644  -0.146588       22059.0    51.470012
#
#    airport_lon  starbucks_dist  starbucks_lat  starbucks_lon  n_club_dist  \
# 0    -0.454478            16.0      51.515100      -0.130180        242.0
# 1    -0.454478            15.0      51.535908      -0.205126       5020.0
# 2    -0.454478            21.0      51.494088      -0.146976       1697.0
# 3    -0.454478            21.0      51.494088      -0.146976       1698.0
# 4    -0.454478           188.0      51.508664      -0.144165         34.0
#
#    n_club_lat  n_club_lon  b_stadium_dist  b_stadium_lat  b_stadium_lon  \
# 0   51.513464   -0.131633           242.0      51.513464      -0.131633
# 1   51.509188   -0.146869          5020.0      51.509188      -0.146869
# 2   51.509188   -0.146869          1697.0      51.509188      -0.146869
# 3   51.509188   -0.146869          1698.0      51.509188      -0.146869
# 4   51.509188   -0.146869            34.0      51.509188      -0.146869
#
#    school_dist  school_lat  school_lon     score
# 0       2675.0   51.496187   -0.106748  1.712154
# 1       8131.0   51.496187   -0.106748  1.676448
# 2       2771.0   51.496187   -0.106748  1.216087
# 3       2771.0   51.496187   -0.106748  1.216075
# 4       3135.0   51.496187   -0.106748  1.166940

# %%
london_cord = [51.509865, -0.118092]

# %%
place_1 = df.loc[0]
place_2 = df.loc[1]
place_3 = df.loc[2]
place_4 = df.loc[3]
place_5 = df.loc[4]
place_5
# Out:
# name              ArcelorMittal
# city                     London
# latitude              51.509644
# longitude             -0.146588
# airport_dist            22059.0
# airport_lat           51.470012
# airport_lon           -0.454478
# starbucks_dist            188.0
# starbucks_lat         51.508664
# starbucks_lon         -0.144165
# n_club_dist                34.0
# n_club_lat            51.509188
# n_club_lon            -0.146869
# b_stadium_dist             34.0
# b_stadium_lat         51.509188
# b_stadium_lon         -0.146869
# school_dist              3135.0
# school_lat            51.496187
# school_lon            -0.106748
# score                   1.16694
# Name: 4, dtype: object

# %%
def map_maker(place):
    coord = [place["latitude"],place["longitude"]]
    maps = Map(location = coord, zoom_start = 15, control_scale = True)
    myicon = Icon(color = "black", prefix = "fa", icon = "fa-solid fa-building")
    company = Marker(location = coord, tooltip = place["name"], icon = myicon)
    company.add_to(maps)
    myicon = Icon(color = "blue", prefix = "fa", icon = "fa-solid fa-plane")
    airport = Marker(location = [place["airport_lat"],place["airport_lon"]], tooltip = "airport", icon = myicon)
    airport.add_to(maps)
    myicon = Icon(color = "red", prefix = "fa", icon ="fa-graduation-cap")
    school = Marker(location = [place["school_lat"],place["school_lon"]], tooltip = "school", icon = myicon)
    school.add_to(maps)
    myicon = Icon(color = "purple", prefix = "fa", icon ="fa-moon-o")
    night= Marker(location = [place["n_club_lat"],place["n_club_lon"]], tooltip = "night_club", icon = myicon)
    night.add_to(maps)
    myicon = Icon(color = "orange", prefix = "fa", icon =" fa-futbol-o")
    stadium = Marker(location = [place["b_stadium_lat"],place["b_stadium_lon"]], tooltip = "night_club", icon = myicon)
    stadium.add_to(maps)
    myicon = Icon(color = "green", prefix = "fa", icon ="fa-coffee")
    bar = Marker(location = [place["starbucks_lat"],place["starbucks_lon"]], tooltip = "night_club", icon = myicon)
    bar.add_to(maps)
    
    return maps

# %%
map_1 = map_maker(place_1)
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e1a777bd54d92c323b4e65aea1d72673 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e1a777bd54d92c323b4e65aea1d72673&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e1a777bd54d92c323b4e65aea1d72673 = L.map(
#                 &quot;map_e1a777bd54d92c323b4e65aea1d72673&quot;,
#                 {
#                     center: [51.515374, -0.130109],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e1a777bd54d92c323b4e65aea1d72673);
#
#
#
#
#
#             var tile_layer_55047da75a1ea2eb8936bd6b2d8ff542 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e1a777bd54d92c323b4e65aea1d72673);
#
#
#             var marker_dd45efd4a936971c6fda5dbc753b1ae8 = L.marker(
#                 [51.515374, -0.130109],
#                 {}
#             ).addTo(map_e1a777bd54d92c323b4e65aea1d72673);
#
#
#             var icon_5862c7b3e4cb2ef923c526252b1674f1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_dd45efd4a936971c6fda5dbc753b1ae8.setIcon(icon_5862c7b3e4cb2ef923c526252b1674f1);
#
#
#             marker_dd45efd4a936971c6fda5dbc753b1ae8.bindTooltip(
#                 `&lt;div&gt;
#                      PCIQ
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0dfc20d749afc204d99947de341fa076 = L.marker(
#                 [51.470012, -0.454478],
#                 {}
#             ).addTo(map_e1a777bd54d92c323b4e65aea1d72673);
#
#
#             var icon_fff13607c363a2dbd1b29da0dfb4f11a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-plane&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0dfc20d749afc204d99947de341fa076.setIcon(icon_fff13607c363a2dbd1b29da0dfb4f11a);
#
#
#             marker_0dfc20d749afc204d99947de341fa076.bindTooltip(
#                 `&lt;div&gt;
#                      airport
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_65d9708b29a3dba7ae8909dc18d52c86 = L.marker(
#                 [51.496187, -0.106748],
#                 {}
#             ).addTo(map_e1a777bd54d92c323b4e65aea1d72673);
#
#
#             var icon_16bcb2728599b4687f6ceaeca2f9ab26 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_65d9708b29a3dba7ae8909dc18d52c86.setIcon(icon_16bcb2728599b4687f6ceaeca2f9ab26);
#
#
#             marker_65d9708b29a3dba7ae8909dc18d52c86.bindTooltip(
#                 `&lt;div&gt;
#                      school
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bbde37c09a0dc61122941e38801d2d6e = L.marker(
#                 [51.513464, -0.131633],
#                 {}
#             ).addTo(map_e1a777bd54d92c323b4e65aea1d72673);
#
#
#             var icon_db9022438dc96bdae31cfb80fa094621 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-moon-o&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_bbde37c09a0dc61122941e38801d2d6e.setIcon(icon_db9022438dc96bdae31cfb80fa094621);
#
#
#             marker_bbde37c09a0dc61122941e38801d2d6e.bindTooltip(
#                 `&lt;div&gt;
#                      night_club
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d960ddad9840e9f0584464d4f538660d = L.marker(
#                 [51.513464, -0.131633],
#                 {}
#             ).addTo(map_e1a777bd54d92c323b4e65aea1d72673);
#
#
#             var icon_70ee17aa4af7d392d384c9ca73f04a89 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot; fa-futbol-o&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d960ddad9840e9f0584464d4f538660d.setIcon(icon_70ee17aa4af7d392d384c9ca73f04a89);
#
#
#             mark

# %%
map_2 = map_maker(place_2)
map_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_628c7e17535dde09e3a545e5250c95ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_628c7e17535dde09e3a545e5250c95ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_628c7e17535dde09e3a545e5250c95ed = L.map(
#                 &quot;map_628c7e17535dde09e3a545e5250c95ed&quot;,
#                 {
#                     center: [51.5359008, -0.2055081],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_628c7e17535dde09e3a545e5250c95ed);
#
#
#
#
#
#             var tile_layer_89e0cfef7d7cfc78305ce814bc647278 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_628c7e17535dde09e3a545e5250c95ed);
#
#
#             var marker_61617bff23db6c9ace384d1ddeafe713 = L.marker(
#                 [51.5359008, -0.2055081],
#                 {}
#             ).addTo(map_628c7e17535dde09e3a545e5250c95ed);
#
#
#             var icon_b37415507537c92ae54dcb554edc8268 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_61617bff23db6c9ace384d1ddeafe713.setIcon(icon_b37415507537c92ae54dcb554edc8268);
#
#
#             marker_61617bff23db6c9ace384d1ddeafe713.bindTooltip(
#                 `&lt;div&gt;
#                      Filmed Media
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_00ff9df5e1cbe3897614730520fdb5b7 = L.marker(
#                 [51.470012, -0.454478],
#                 {}
#             ).addTo(map_628c7e17535dde09e3a545e5250c95ed);
#
#
#             var icon_db0d067fb1d3a6234c3c25b24f2a8683 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-plane&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_00ff9df5e1cbe3897614730520fdb5b7.setIcon(icon_db0d067fb1d3a6234c3c25b24f2a8683);
#
#
#             marker_00ff9df5e1cbe3897614730520fdb5b7.bindTooltip(
#                 `&lt;div&gt;
#                      airport
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_777e4a65df0dc87a04df3d68afeff55d = L.marker(
#                 [51.496187, -0.106748],
#                 {}
#             ).addTo(map_628c7e17535dde09e3a545e5250c95ed);
#
#
#             var icon_1e0e68e5fca338814a3a79e05469c093 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_777e4a65df0dc87a04df3d68afeff55d.setIcon(icon_1e0e68e5fca338814a3a79e05469c093);
#
#
#             marker_777e4a65df0dc87a04df3d68afeff55d.bindTooltip(
#                 `&lt;div&gt;
#                      school
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c348c330c6d34569383d1cf1fb5cb5a1 = L.marker(
#                 [51.509188, -0.146869],
#                 {}
#             ).addTo(map_628c7e17535dde09e3a545e5250c95ed);
#
#
#             var icon_9a8c67377de76fb9fd579de7d69e0c51 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-moon-o&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c348c330c6d34569383d1cf1fb5cb5a1.setIcon(icon_9a8c67377de76fb9fd579de7d69e0c51);
#
#
#             marker_c348c330c6d34569383d1cf1fb5cb5a1.bindTooltip(
#                 `&lt;div&gt;
#                      night_club
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c325ede1d678de60eefec85c1f75c03d = L.marker(
#                 [51.509188, -0.146869],
#                 {}
#             ).addTo(map_628c7e17535dde09e3a545e5250c95ed);
#
#
#             var icon_d94084ec72649e0519771c3870b6f6e5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot; fa-futbol-o&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c325ede1d678de60eefec85c1f75c03d.setIcon(icon_d94084ec72649e0519771c3870b6f6e5);

# %%
map_3 = map_maker(place_3)
map_3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35b56a4d43c3c6b2573b5e3fe4f8fcc1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35b56a4d43c3c6b2573b5e3fe4f8fcc1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_35b56a4d43c3c6b2573b5e3fe4f8fcc1 = L.map(
#                 &quot;map_35b56a4d43c3c6b2573b5e3fe4f8fcc1&quot;,
#                 {
#                     center: [51.4940757, -0.146659],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_35b56a4d43c3c6b2573b5e3fe4f8fcc1);
#
#
#
#
#
#             var tile_layer_d90db18de507d7bdb36ed53f99787c17 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_35b56a4d43c3c6b2573b5e3fe4f8fcc1);
#
#
#             var marker_b43b1c3668239ce84a23c65e877d63f1 = L.marker(
#                 [51.4940757, -0.146659],
#                 {}
#             ).addTo(map_35b56a4d43c3c6b2573b5e3fe4f8fcc1);
#
#
#             var icon_3d45b838a95bf9f993ba74733cc566a5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b43b1c3668239ce84a23c65e877d63f1.setIcon(icon_3d45b838a95bf9f993ba74733cc566a5);
#
#
#             marker_b43b1c3668239ce84a23c65e877d63f1.bindTooltip(
#                 `&lt;div&gt;
#                      Zensify
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8df5ac8c0357b29126da99c1d1e05c57 = L.marker(
#                 [51.470012, -0.454478],
#                 {}
#             ).addTo(map_35b56a4d43c3c6b2573b5e3fe4f8fcc1);
#
#
#             var icon_cf285424924f0821d59e56f8f2fa0de2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-plane&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8df5ac8c0357b29126da99c1d1e05c57.setIcon(icon_cf285424924f0821d59e56f8f2fa0de2);
#
#
#             marker_8df5ac8c0357b29126da99c1d1e05c57.bindTooltip(
#                 `&lt;div&gt;
#                      airport
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5750e55d61d323a661109d82547ff75e = L.marker(
#                 [51.496187, -0.106748],
#                 {}
#             ).addTo(map_35b56a4d43c3c6b2573b5e3fe4f8fcc1);
#
#
#             var icon_603fd9e3b4031e642a409bc7a0d155ad = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5750e55d61d323a661109d82547ff75e.setIcon(icon_603fd9e3b4031e642a409bc7a0d155ad);
#
#
#             marker_5750e55d61d323a661109d82547ff75e.bindTooltip(
#                 `&lt;div&gt;
#                      school
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_410499e4616a49ddb48888e57f42a03f = L.marker(
#                 [51.509188, -0.146869],
#                 {}
#             ).addTo(map_35b56a4d43c3c6b2573b5e3fe4f8fcc1);
#
#
#             var icon_ef980395a783bd277686ca38b2185fcc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-moon-o&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_410499e4616a49ddb48888e57f42a03f.setIcon(icon_ef980395a783bd277686ca38b2185fcc);
#
#
#             marker_410499e4616a49ddb48888e57f42a03f.bindTooltip(
#                 `&lt;div&gt;
#                      night_club
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0bbf0ada63e7ba973826495a55e0d698 = L.marker(
#                 [51.509188, -0.146869],
#                 {}
#             ).addTo(map_35b56a4d43c3c6b2573b5e3fe4f8fcc1);
#
#
#             var icon_01cc03af085f5f00c3b1271a467c34b2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot; fa-futbol-o&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0bbf0ada63e7ba973826495a55e0d698.setIcon(icon_01cc03af085f5f00c3b1271a467c34b2);

# %%
map_4 = map_maker(place_4)
map_4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2018b37501b1ee85820b9f114b0cbb3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2018b37501b1ee85820b9f114b0cbb3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a2018b37501b1ee85820b9f114b0cbb3 = L.map(
#                 &quot;map_a2018b37501b1ee85820b9f114b0cbb3&quot;,
#                 {
#                     center: [51.494067, -0.146665],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_a2018b37501b1ee85820b9f114b0cbb3);
#
#
#
#
#
#             var tile_layer_f3ccd9546882b522d126efe261f5adba = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a2018b37501b1ee85820b9f114b0cbb3);
#
#
#             var marker_93bcfc7cafb9b41110b715c45fd274d3 = L.marker(
#                 [51.494067, -0.146665],
#                 {}
#             ).addTo(map_a2018b37501b1ee85820b9f114b0cbb3);
#
#
#             var icon_3877f32d6c6217a2852581f180f3003f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_93bcfc7cafb9b41110b715c45fd274d3.setIcon(icon_3877f32d6c6217a2852581f180f3003f);
#
#
#             marker_93bcfc7cafb9b41110b715c45fd274d3.bindTooltip(
#                 `&lt;div&gt;
#                      ProcServe
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0e50b7c74e41a5d2aa3cafd91f7470b2 = L.marker(
#                 [51.470012, -0.454478],
#                 {}
#             ).addTo(map_a2018b37501b1ee85820b9f114b0cbb3);
#
#
#             var icon_3dbbd2bb247523750922524b271bc98d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-plane&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0e50b7c74e41a5d2aa3cafd91f7470b2.setIcon(icon_3dbbd2bb247523750922524b271bc98d);
#
#
#             marker_0e50b7c74e41a5d2aa3cafd91f7470b2.bindTooltip(
#                 `&lt;div&gt;
#                      airport
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_07e42c7b448765c9ff1bec177f22c911 = L.marker(
#                 [51.496187, -0.106748],
#                 {}
#             ).addTo(map_a2018b37501b1ee85820b9f114b0cbb3);
#
#
#             var icon_de0e01cc0f0768db2645698fbef24438 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_07e42c7b448765c9ff1bec177f22c911.setIcon(icon_de0e01cc0f0768db2645698fbef24438);
#
#
#             marker_07e42c7b448765c9ff1bec177f22c911.bindTooltip(
#                 `&lt;div&gt;
#                      school
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_eedff072a02fe08950c95a17bf91b9f3 = L.marker(
#                 [51.509188, -0.146869],
#                 {}
#             ).addTo(map_a2018b37501b1ee85820b9f114b0cbb3);
#
#
#             var icon_2f5fc51f874bec4b4475aa9b1a1fec93 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-moon-o&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_eedff072a02fe08950c95a17bf91b9f3.setIcon(icon_2f5fc51f874bec4b4475aa9b1a1fec93);
#
#
#             marker_eedff072a02fe08950c95a17bf91b9f3.bindTooltip(
#                 `&lt;div&gt;
#                      night_club
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_99bd4983b436e7467d04668c1c8664d3 = L.marker(
#                 [51.509188, -0.146869],
#                 {}
#             ).addTo(map_a2018b37501b1ee85820b9f114b0cbb3);
#
#
#             var icon_9381c6209962a50796d8aa24a0ef4319 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot; fa-futbol-o&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_99bd4983b436e7467d04668c1c8664d3.setIcon(icon_9381c6209962a50796d8aa24a0ef4319);

# %%
map_5 = map_maker(place_5)
map_5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6abc8be7e7345f1a9b4eaf2d3f3d65a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6abc8be7e7345f1a9b4eaf2d3f3d65a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6abc8be7e7345f1a9b4eaf2d3f3d65a4 = L.map(
#                 &quot;map_6abc8be7e7345f1a9b4eaf2d3f3d65a4&quot;,
#                 {
#                     center: [51.5096437, -0.146588],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_6abc8be7e7345f1a9b4eaf2d3f3d65a4);
#
#
#
#
#
#             var tile_layer_205bbbbae41bd4c9248a768b8f450cce = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6abc8be7e7345f1a9b4eaf2d3f3d65a4);
#
#
#             var marker_860ada4819796031af2fe38f68c586a4 = L.marker(
#                 [51.5096437, -0.146588],
#                 {}
#             ).addTo(map_6abc8be7e7345f1a9b4eaf2d3f3d65a4);
#
#
#             var icon_0d0e0002a9be320400690bdfacc597a7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_860ada4819796031af2fe38f68c586a4.setIcon(icon_0d0e0002a9be320400690bdfacc597a7);
#
#
#             marker_860ada4819796031af2fe38f68c586a4.bindTooltip(
#                 `&lt;div&gt;
#                      ArcelorMittal
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2956c00d9be33341605fa81587b46091 = L.marker(
#                 [51.470012, -0.454478],
#                 {}
#             ).addTo(map_6abc8be7e7345f1a9b4eaf2d3f3d65a4);
#
#
#             var icon_91ecd16e0e74fe0e2e26c4cd1b16d5cc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-plane&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_2956c00d9be33341605fa81587b46091.setIcon(icon_91ecd16e0e74fe0e2e26c4cd1b16d5cc);
#
#
#             marker_2956c00d9be33341605fa81587b46091.bindTooltip(
#                 `&lt;div&gt;
#                      airport
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b8faa42636480c62c55d29681e6ffeac = L.marker(
#                 [51.496187, -0.106748],
#                 {}
#             ).addTo(map_6abc8be7e7345f1a9b4eaf2d3f3d65a4);
#
#
#             var icon_771b258d0aa42bed02e76ff595ea477d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-graduation-cap&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b8faa42636480c62c55d29681e6ffeac.setIcon(icon_771b258d0aa42bed02e76ff595ea477d);
#
#
#             marker_b8faa42636480c62c55d29681e6ffeac.bindTooltip(
#                 `&lt;div&gt;
#                      school
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c2dba103f389ad3b75dfe54c5850a086 = L.marker(
#                 [51.509188, -0.146869],
#                 {}
#             ).addTo(map_6abc8be7e7345f1a9b4eaf2d3f3d65a4);
#
#
#             var icon_e64b8539c25b87ed8f9b3814338b8ce1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-moon-o&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c2dba103f389ad3b75dfe54c5850a086.setIcon(icon_e64b8539c25b87ed8f9b3814338b8ce1);
#
#
#             marker_c2dba103f389ad3b75dfe54c5850a086.bindTooltip(
#                 `&lt;div&gt;
#                      night_club
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_05327733619f4c9bdc222fc946698607 = L.marker(
#                 [51.509188, -0.146869],
#                 {}
#             ).addTo(map_6abc8be7e7345f1a9b4eaf2d3f3d65a4);
#
#
#             var icon_0e3f549f742fa668d0bf3bca9b02edaf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot; fa-futbol-o&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_05327733619f4c9bdc222fc946698607.setIcon(icon_0e3f549f742fa668d0bf3bca9b02edaf);
